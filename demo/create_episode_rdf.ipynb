# %%
import IPython.display
import sys
from rdflib import *
from rdflib.collection import Collection
import glob
import os
import re
import random
import csv
import itertools
from SPARQLWrapper import SPARQLWrapper, JSON, BASIC

# %%
def getFirstAndFinalStates(auth, activity, scene):
    result = None
    queryString = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX : <http://example.org/virtualhome2kg/ontology/>
PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?s ?startState ?startStateType ?startObject ?endState ?endStateType ?endObject WHERE {
    <%activity> :hasEvent ?startEvent, ?endEvent .
    # ?startEvent a :StartEvent .
    # ?endEvent a :EndEvent .
    # ?startEvent :situationBeforeEvent ?startSituation ;
        ho:object ?startObject .
    # ?startState :partOf ?startSituation ;
        :isStateOf ?startObject ;
        :state ?startStateType .
    # ?endEvent :situationAfterEvent ?endSituation ;
        ho:object ?endObject .
    # ?endState :partOf ?endSituation ;
        :isStateOf ?endObject ;
        :state ?endStateType .
}
    """
    sparql = SPARQLWrapper(auth[0] + "_event_" + scene)
    sparql.setHTTPAuth(BASIC)
    sparql.setCredentials(auth[1], auth[2])
    queryString = queryString.replace("%activity", activity)
    sparql.setQuery(queryString)
    sparql.setReturnFormat(JSON)

    try :
        json = sparql.query().convert()
        bindings = json['results']['bindings']
        result = bindings
    except  Exception as e:
        print(e)
    return result

# %%
def readEpisode(path):
    with open(path) as f:
        reader = csv.reader(f)
        results = [row[0] for row in reader]
        results.pop(0)
        episodes = [episode.split(" → ") for episode in results]
        return episodes

# %%
def getActivity(auth, activity_name, scene):
    result = []
    queryString = """
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        select distinct *
        where { 
            # ?s a ho:%s ;
                rdfs:comment ?comment .
        } ORDER BY RAND() limit 1 
    """
    sparql = SPARQLWrapper(auth[0] + "_event_" + scene)
    sparql.setHTTPAuth(BASIC)
    sparql.setCredentials(auth[1], auth[2])
    sparql.setQuery(queryString % activity_name)
    sparql.setReturnFormat(JSON)

    try :
        json = sparql.query().convert()
        bindings = json['results']['bindings']
        result.append(bindings[0]['s']['value'])
        result.append(bindings[0]['comment']['value'])
    except  Exception as e:
        print(e)
        result = e
    return result

# %%
def checkConsistency(activity1_value, activity2_value):
    finalStateList1 = activity1_value["endState"]
    firstStateList2 = activity2_value["startState"]
    executable = True
    for finalState in finalStateList1:
        finalStateObject = stateMap[finalState]["object"]
        finalStateTypes = stateMap[finalState]["state"]
        for firstState in firstStateList2:
            firstStateObject = stateMap[firstState]["object"]
            firstStateTypes = stateMap[firstState]["state"]
            if finalStateObject == firstStateObject:
                for finalStateType in finalStateTypes:
                    if finalStateType in inverse_states:
                        if inverse_states[finalStateType] in firstStateTypes:
                            #print([finalStateType, firstStateTypes])
                            #さらに、そのobjectがactivtyの対象になっているかチェックし、対象となっていなければ上書きする
                            executable = checkTargetObject(firstState)
                            assert executable
                    else:
                        #print([finalState, firstState])
                        continue
    return executable

# %%
def checkTargetObject(auth, state):
    queryString = """
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        ASK { 
            <%s> :partOf ?situation ;
                      :isStateOf ?object .
            # ?action (:situationBeforeAction|:situationAfterAction) ?situation .
            # ?activity :action ?action ;
                      :action ?allActions .
            # ?allActions ho:object ?object .
        }
    """
    sparql = SPARQLWrapper(auth[0])
    sparql.setHTTPAuth(BASIC)
    sparql.setCredentials(auth[1], auth[2])
    sparql.setQuery(queryString % state)
    sparql.setReturnFormat(JSON)

    try :
        json = sparql.query().convert()
        if json['boolean'] is True:
            result = False
        else:
            result = True
    except  Exception as e:
        print(e)
        result = e
    return result

# %%
def getTTLFileName(activity, scene):
    ttl_file_activity = activity.replace("http://example.org/virtualhome2kg/instance/","")
    ttl_file_activity = ttl_file_activity.replace("_"+scene, "")
    m = re.search(r'\d+',ttl_file_activity)
    activity_name = re.split(r'\d+',ttl_file_activity)[0]
    activity_id = m.group()
    file_name = "virtualhome2kg-" + activity_name.capitalize() + "-" + activity_id + ".ttl"
    return file_name

# %%
def replicateActivity(g, scene, ep_id):
    queryString = """
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        SELECT DISTINCT ?s WHERE {
            # ?s a ?class .
            filter ((?class = ho:Activity) || (?class = :Event) || (?class = :StartEvent) || (?class =:EndEvent) || (?class = :Situation) || (?class = :State) || (?class = ho:Shape))
        }
    """
    qres = g.query(queryString)
    for res in qres:
        replica = res.s + "_ep" + str(ep_id)
        g.add((URIRef(replica),res.p,res.o))
    print(g.serialize('test.ttl',format="ttl"))
    #主語になるもののURIをすべて改変して複製

# %%
def update(g, activity1, activity2, scene, auth):
    result = None

    # activity2のttlを取得する
    file_name2 = getTTLFileName(activity2, scene)

    # ttlをロードして結合処理
    g.parse("rdf/" + scene + "/" + file_name2, format='turtle')
    queryString = """
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX owl: <http://www.w3.org/2002/07/owl#>
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        DELETE {
            # ?startState :partOf ?situation ;
                rdf:type :State ;
                :isStateOf ?object ;
                :nextState ?nextState .
        } INSERT {
            # ?activity1 :nextActivity ?activity2 .
            # ?endState :partOf ?situation ; 
                        :nextState ?nextState .
        } WHERE {
            BIND(<%activity1> AS ?activity1)
            # ?activity1 :hasEvent ?endEvent .
            # ?endEvent a :EndEvent .
            # ?endEvent :situationAfterEvent ?endSituation .
            # ?endState :partOf ?endSituation ;
                        :isStateOf ?object .
            BIND(<%activity2> AS ?activity2)
            # ?activity2 :hasEvent ?startEvent .
            # ?startEvent a :StartEvent .
            # ?startEvent :situationBeforeEvent ?startSituation .
            # ?startState :partOf ?startSituation ;
                        :isStateOf ?object .
            # ?startState :partOf ?situation .
            optional {?startState :nextState ?nextState}
        }
    """
    queryString = queryString.replace("%activity1", activity1)
    queryString = queryString.replace("%activity2", activity2)

#     sparql = SPARQLWrapper(auth[0] + "/statements")
#     sparql.setHTTPAuth(BASIC)
#     sparql.setCredentials(auth[1], auth[2])
#     sparql.method = "POST"
#     sparql.queryType = "INSERT"
#     sparql.setQuery(queryString)
#     sparql.setReturnFormat(JSON)
#     try :
#         qres = g.query(queryString)
#         result = qres
    g.update(queryString)
#         json = sparql.query().convert()
#         bindings = json
#         result = bindings
#     except  Exception as e:
#         print(e)
    return g

# %%
def checkNextActivityIsRoutined(g, activity2):
    result = None
    queryString = """
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX owl: <http://www.w3.org/2002/07/owl#>
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        ASK {
            # ?prevActivity :nextActivity <%activity2> .
        }
    """
    
    try :
        qres = g.query(queryString.replace("%activity2", activity2))
        result = [row for row in qres][0]
    except  Exception as e:
        print(e)
    return result

# %%
def addNextState(g, activity1, activity2):
    result = None
    queryString = """
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX owl: <http://www.w3.org/2002/07/owl#>
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        INSERT {
            # ?prevState :nextState ?startState .
        } WHERE {
            <%activity1> :hasEvent ?endEvent .
            # ?endEvent a :EndEvent ;
                    :situationAfterEvent ?endSituation .
            # ?endState :partOf ?endSituation ;
                        :isStateOf ?object .
            # ?prevState :nextState ?endState .
            BIND(<%activity2> AS ?activity2)
            # ?activity2 :hasEvent ?startEvent .
            # ?startEvent a :StartEvent ;
                        :situationBeforeEvent ?startSituation .
            # ?startState :partOf ?startSituation ;
                        :isStateOf ?object .
        }
    """
    try :
        queryString = queryString.replace("%activity1", activity1)
        queryString = queryString.replace("%activity2", activity2)
        g.update(queryString)
    except  Exception as e:
        print(e.args)
    return g

# %%
def deleteFinalState(g, activity1, activity2):
    result = None
    queryString = """
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX owl: <http://www.w3.org/2002/07/owl#>
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        DELETE {
            # ?finalState ?p ?o .
        } WHERE {
            <%activity1> :hasEvent ?endEvent .
            # ?endEvent a :EndEvent ;
                    :situationAfterEvent ?endSituation .
            # ?endState :partOf ?endSituation ;
                        :isStateOf ?object .
            # ?endState ?p ?o .
            <%activity2> :hasEvent ?startEvent .
            # ?startEvent a :StartEvent ;
                        :situationBeforeEvent ?startSituation .
            # ?startState :partOf ?startSituation ;
                        :isStateOf ?object .
        }
    """
    try :
        queryString = queryString.replace("%activity1", activity1)
        queryString = queryString.replace("%activity2", activity2)
        g.update(queryString)
    except  Exception as e:
        print(e.args)
    return g

# %%
def updateRoutine(g, activity1, activity2):
    result = None
    queryString = """
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX owl: <http://www.w3.org/2002/07/owl#>
        PREFIX : <http://example.org/virtualhome2kg/ontology/>
        PREFIX ho: <http://www.owl-ontologies.com/VirtualHome.owl#>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        INSERT { 
            <%activity1> :nextActivity <%activity2> .
            # ?startState :partOf ?situation .
        } WHERE {
            {
                <%activity1> :hasEvent ?endEvent .
                # ?endEvent a :EndEvent ;
                            :situationAfterEvent ?endSituation .
                # ?endState :partOf ?endSituation ;
                            :isStateOf ?object .

                <%activity2> :hasEvent ?startEvent .
                # ?startEvent a :StartEvent ;
                            :situationBeforeEvent ?startSituation .
                # ?startState :partOf ?startSituation ;
                            :isStateOf ?object .
            } union {
                <%activity1> :hasEvent ?endEvent .
                # ?endEvent a :EndEvent ;
                            :situationAfterEvent ?endSituation .
                # ?endState :partOf ?endSituation ;
                            :partOf ?situation .
            }
        }
    """
    try :
        queryString = queryString.replace("%activity1", activity1)
        queryString = queryString.replace("%activity2", activity2)
        g.update(queryString)
    except  Exception as e:
        print(e.args)
    return g

# %%
def preprocess(auth, activity, scene, activityMap, stateMap):
    #get objects' first/final states
    bindings = getFirstAndFinalStates(auth, activity, scene)

    try:
        #preprocess
        for elem in bindings:
            firstState = elem['startState']['value']
            finalState = elem['endState']['value']
            #firstStateに関してstateMapの作成
            if 'firstStateType' in elem:
                if firstState not in stateMap:
                    stateMap[firstState] = {
                        "state": [elem['startStateType']['value']],
                        "object": elem['endObject']['value']
                    }
                else:
                    if elem['startStateType']['value'] not in stateMap[firstState]['state']:
                        stateMap[firstState]['state'].append(elem['startStateType']['value'])
            else:
                if firstState not in stateMap:
                    stateMap[firstState] = {
                        "state": [],
                        "object": elem['startObject']['value']
                    }
                else:
                    pass

            #endStateに関してstateMapの作成
            if  'endStateType' in elem:
                if finalState not in stateMap:
                    stateMap[finalState] = {
                        "state": [elem['endStateType']['value']],
                        "object": elem['endObject']['value']
                    }
                else:
                    if elem['endStateType']['value'] not in stateMap[finalState]['state']:
                        stateMap[finalState]['state'].append(elem['endStateType']['value'])
            else:
                if finalState not in stateMap:
                    stateMap[finalState] = {
                        "state": [],
                        "object": elem['endObject']['value']
                    }
                else:
                    pass

            if activity in activityMap:
                if firstState not in activityMap[activity]['startState']:
                    activityMap[activity]['startState'].append(firstState)
                if finalState not in activityMap[activity]['endState']:
                    activityMap[activity]['endState'].append(finalState)
            else:
                #activity初出時
                activityMap[activity] = {
                    'startState': [firstState],
                    'endState': [finalState]
                }
    except Except as e:
        print(e.args)
    return activityMap, stateMap

# %%
def loadAuthFile(path):
    with open(path) as f:
        auth =  f.readlines()
        auth = [x.replace('\n','') for x in auth]
    return auth

# %%
inverse_states = {
    "http://example.org/virtualhome2kg/ontology/CLOSED": "http://example.org/virtualhome2kg/ontology/OPEN",
    "http://example.org/virtualhome2kg/ontology/OFF": "http://example.org/virtualhome2kg/ontology/ON",
    "http://example.org/virtualhome2kg/ontology/DIRTY": "http://example.org/virtualhome2kg/ontology/CLEAN",
    "http://example.org/virtualhome2kg/ontology/PLUGGED_IN": "http://example.org/virtualhome2kg/ontology/PLUGGED_OUT",
    "http://example.org/virtualhome2kg/ontology/OPEN": "http://example.org/virtualhome2kg/ontology/CLOSED",
    "http://example.org/virtualhome2kg/ontology/ON": "http://example.org/virtualhome2kg/ontology/OFF",
    "http://example.org/virtualhome2kg/ontology/CLEAN": "http://example.org/virtualhome2kg/ontology/DIRTY",
    "http://example.org/virtualhome2kg/ontology/PLUGGED_OUT": "http://example.org/virtualhome2kg/ontology/PLUGGED_IN"
}

# %%
auth = loadAuthFile("auth_markov_chain.txt")
scene = "scene1"
data_path = "episodes/lancers/*.csv"
list_num = 0
for file_path in glob.glob(data_path):
    list_num += 1
    episode_list = readEpisode(file_path)
    executable_routine = 0
    executable_episode_list = []
    executable_episode_desc_list = []
    base = Namespace("http://example.org/virtualhome2kg/instance/")
    onto = Namespace("http://example.org/virtualhome2kg/ontology/")
    # replicateActivity("http://example.org/virtualhome2kg/instance/bring_dirty_plate_to_sink0_scene4", scene,1)
    episode_num = 1
    for episode in episode_list:
        activity_list = []
        activity_desc_list = []
        for activity in episode:
            activity = activity.replace(' ', '_')
            activity = activity.lower()
            activity_description = getActivity(auth, activity, scene)
            activity_list.append(activity_description[0])
            activity_desc_list.append(activity_description[1])
        activityMap = {}
        stateMap = {}

        #check consistency
        for i in range(len(activity_list)-1):
            activity1 = activity_list[i]
            activity2 = activity_list[i+1]
            activityMap, stateMap = preprocess(auth, activity1, scene, activityMap, stateMap)
            activityMap, stateMap = preprocess(auth, activity2, scene, activityMap, stateMap)
            consistency = True
            statesChanged = True
            activity1_value = None
            activity2_value = None
            if activity1 == activity2:
                consistency = False
                break

            if activity1 in activityMap:
                activity1_value = activityMap[activity1]
                if activity2 in activityMap:
                    activity2_value = activityMap[activity2]
                else:
                    # if there is no state changed
                    statesChanged = False
            else:
                # if there is no state changed
                statesChanged = False

            #print([activity1, activity2])
            try:
                if statesChanged:
                    assert checkConsistency(activity1_value, activity2_value)
            except Exception as e:
                consistency = False
                break

        #SPARQL DELETE/INSERT query
        if consistency:
            print("Executable")
            print(episode)
            executable_routine += 1
            executable_episode_list.append(episode)
            executable_episode_desc_list.append(activity_desc_list)
            g = Graph()
            for i in range(len(activity_list)-1):
                activity1 = activity_list[i]
                activity2 = activity_list[i+1]
                if checkNextActivityIsRoutined(g, activity2):
                    g = deleteFinalState(g, activity1, activity2)
                    g = updateRoutine(g, activity1, activity2)
                    g = addNextState(g, activity1,activity2)
                    print(str(i) + " updatedRoutine: " + activity1 + " " + activity2)
                else:
                    if i == 0:
                        file_name1 = getTTLFileName(activity1, scene)
                        g.parse("rdf/" + scene + "/" + file_name1, format='turtle')
                    g = update(g, activity1=activity1, activity2=activity2, scene=scene, auth=auth)
                # qres = update(g, activity1=activity1, activity2=activity2, scene=scene)
                # for res in qres:
                #     print(res)
                print(str(i) + " updated: " + activity1 + " " + activity2)

            # create episode resource
            episode_r = base["episode" + str(list_num) + "_" + str(episode_num)]
            g.add((episode_r, RDF.type, onto.Episode))
            activity_num = 1
            for activity in activity_list:
                g.add((episode_r, onto.hasActivity, URIRef(activity)))
                g.add((URIRef(activity), onto.activitiyNumber, Literal(activity_num, datatype=XSD.int)))
                activity_num += 1

            ttl_file = "rdf/episode_" + scene + "/episode_list" + str(list_num) + "_" + str(episode_num) + "_" + scene + "_20211003.ttl"
            g.serialize(destination=ttl_file, format="turtle")

            # change URI
            data_lines = None
            with open(ttl_file) as f:
                data_lines = f.read()
            for activity in activity_list:
                activity_name = activity.replace("http://example.org/virtualhome2kg/instance/","")
                if activity_name + "_ep" not in data_lines:
                    data_lines = data_lines.replace(activity_name, activity_name + "_ep" + str(list_num) + "_" + str(episode_num))
            with open(ttl_file, mode="w") as f:
                f.write(data_lines)

            episode_num += 1
    #         sys.exit()
        else:
            print("not executable")
# Out:
# Executable
# ['Watch youtube', 'Take nap', 'Cook some food', 'Breakfast', 'Read book', 'Wash teeth']
# 0 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/take_nap0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/cook_some_food1_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/cook_some_food1_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/read_book22_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/read_book22_scene1 http://example.org/virtualhome2kg/instance/wash_teeth6_scene1
# Executable
# ['Make toast', 'Have snack', 'Watch youtube', 'Watch movie', 'Write an email', 'Use computer']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/write_an_email14_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/write_an_email14_scene1 http://example.org/virtualhome2kg/instance/use_computer1_scene1
# Executable
# ['Write an email', 'Type up document', 'Wash dishes', 'Wipe down sink', 'Wash hands', 'Cook some food']
# 0 updated: http://example.org/virtualhome2kg/instance/write_an_email16_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes5_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes5_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_hands23_scene1 http://example.org/virtualhome2kg/instance/cook_some_food3_scene1
# Executable
# ['Surf net', 'Make toast', 'Have snack', 'Wipe down sink', 'Play musical chairs', 'Wash hands']
# 0 updated: http://example.org/virtualhome2kg/instance/surf_net0_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/play_musical_chairs0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/play_musical_chairs0_scene1 http://example.org/virtualhome2kg/instance/wash_hands20_scene1
# Executable
# ['Cook some food', 'Watch youtube', 'Wash teeth', 'Watch movie', 'Wash monitor', 'Breakfast']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food2_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth4_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_teeth4_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/wash_monitor0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_monitor0_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# Executable
# ['Sleep', 'Wash hands', 'Breakfast', 'Have snack', 'Wipe down sink', 'Take shower']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep1_scene1 http://example.org/virtualhome2kg/instance/wash_hands22_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands22_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/take_shower0_scene1
# Executable
# ['Keep an eye on stove as something is cooking', 'Relax on sofa', 'Dust', 'Watch movie', 'Clean', 'Wash sink']
# 0 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/dust0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/dust0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/clean2_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/clean2_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# Executable
# ['Sleep', 'Wash hands', 'Relax on sofa', 'Make coffee', 'Eat', 'Oil dining room']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep2_scene1 http://example.org/virtualhome2kg/instance/wash_hands11_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands11_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1 http://example.org/virtualhome2kg/instance/make_coffee0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/eat0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/eat0_scene1 http://example.org/virtualhome2kg/instance/oil_dining_room0_scene1
# Executable
# ['Keep an eye on stove as something is cooking', 'Type up document', 'Wash dishes', 'Wash hands', 'Go to sleep', 'Wash hands']
# 0 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes0_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_hands23_scene1 http://example.org/virtualhome2kg/instance/go_to_sleep3_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/go_to_sleep3_scene1 http://example.org/virtualhome2kg/instance/wash_hands20_scene1
# Executable
# ['Breakfast', 'Type up document', 'Drink', 'Wash sink', 'Wash hands', 'Surf net']
# 0 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/drink19_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/drink19_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_hands23_scene1 http://example.org/virtualhome2kg/instance/surf_net0_scene1
# Executable
# ['Watch youtube', 'Cut bread', 'Relax on sofa', 'Wash monitor', 'Wash teeth', 'Breakfast']
# 0 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/cut_bread0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/cut_bread0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa27_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa27_scene1 http://example.org/virtualhome2kg/instance/wash_monitor0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_monitor0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth5_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth5_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# Executable
# ['Make coffee', 'Have snack', 'Wash hands', 'Surf web for money legitimate making opportunities', 'Type up document', 'Keep an eye on stove as something is cooking']
# 0 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/wash_hands13_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_hands13_scene1 http://example.org/virtualhome2kg/instance/surf_web_for_money_legitimate_making_opportunities0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/surf_web_for_money_legitimate_making_opportunities0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# Executable
# ['Watch movie', 'Write an email', 'Cook some food', 'Relax on sofa', 'Wash sink', 'Browse internet']
# 0 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/write_an_email9_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/write_an_email9_scene1 http://example.org/virtualhome2kg/instance/cook_some_food5_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/cook_some_food5_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/browse_internet18_scene1
# Executable
# ['Surf net', 'Wash teeth', 'Watch youtube', 'Wash hands', 'Watch youtube', 'Cut bread']
# 0 updated: http://example.org/virtualhome2kg/instance/surf_net0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth7_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_teeth7_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/wash_hands15_scene1
# 3 updatedRoutine: http://example.org/virtualhome2kg/instance/wash_hands15_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_hands15_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/cut_bread0_scene1
# Executable
# ['Watch movie', 'Watch youtube', 'Wash dishes by hand', 'Wash teeth', 'Relax on sofa', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_by_hand8_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes_by_hand8_scene1 http://example.org/virtualhome2kg/instance/wash_teeth1_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_teeth1_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# Executable
# ['Take nap', 'Wash hands', 'Cook some food', 'Drink', 'Wash dirty dishes', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/wash_hands18_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands18_scene1 http://example.org/virtualhome2kg/instance/cook_some_food5_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/cook_some_food5_scene1 http://example.org/virtualhome2kg/instance/drink20_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/drink20_scene1 http://example.org/virtualhome2kg/instance/wash_dirty_dishes0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_dirty_dishes0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# Executable
# ['Sleep', 'Wash teeth', 'Make toast', 'Have snack', 'Wash dishes with dishwasher', 'Wipe down sink']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth7_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_teeth7_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher16_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher16_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# Executable
# ['Surf internet', 'Wash dishes with dishwasher', 'Sleep', 'Wash face', 'Write story', 'Walk to room']
# 0 updated: http://example.org/virtualhome2kg/instance/surf_internet0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher18_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher18_scene1 http://example.org/virtualhome2kg/instance/sleep3_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/sleep3_scene1 http://example.org/virtualhome2kg/instance/wash_face0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_face0_scene1 http://example.org/virtualhome2kg/instance/write_story0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/write_story0_scene1 http://example.org/virtualhome2kg/instance/walk_to_room0_scene1
# Executable
# ['Take nap', 'Wash teeth', 'Wash face', 'Make toast', 'Relax on sofa', 'Wipe down sink']
# 0 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth8_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_teeth8_scene1 http://example.org/virtualhome2kg/instance/wash_face0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_face0_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# Executable
# ['Relax on sofa', 'Wash hands', 'Watch youtube', 'Wash dishes with dishwasher', 'Wash teeth', 'Make toast']
# 0 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/wash_hands21_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands21_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1 http://example.org/virtualhome2kg/instance/wash_teeth3_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth3_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# Executable
# ['Sleep', 'Breakfast', 'Type up document', 'Wash dishes with dishwasher', 'Wipe down sink', 'Wash hands']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep0_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher15_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher15_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# Executable
# ['Wash sink', 'Go to toilet', 'Cut bread', 'Relax on sofa', 'Watch youtube', 'Drink']
# 0 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/go_to_toilet0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/go_to_toilet0_scene1 http://example.org/virtualhome2kg/instance/cut_bread0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/cut_bread0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/drink19_scene1
# Executable
# ['Breakfast', 'Relax on sofa', 'Wash sink', 'Wash hands', 'Shred receipts', 'Read book']
# 0 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa19_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa19_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_hands22_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_hands22_scene1 http://example.org/virtualhome2kg/instance/shred_receipts0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/shred_receipts0_scene1 http://example.org/virtualhome2kg/instance/read_book19_scene1
# Executable
# ['Write an email', 'Send  email', 'Use computer', 'Wash teeth', 'Relax on sofa', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/write_an_email16_scene1 http://example.org/virtualhome2kg/instance/send__email0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/send__email0_scene1 http://example.org/virtualhome2kg/instance/use_computer2_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/use_computer2_scene1 http://example.org/virtualhome2kg/instance/wash_teeth0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_teeth0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1 http://example.org/virtualhome2kg/instance/watch_movie2_scene1
# Executable
# ['Watch youtube', 'Make toast', 'Have snack', 'Wash dishes', 'Cut bread', 'Breakfast']
# 0 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes5_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_dishes5_scene1 http://example.org/virtualhome2kg/instance/cut_bread0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/cut_bread0_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# Executable
# ['Make coffee', 'Relax on sofa', 'Shred receipts', 'Wipe down baseboards please', 'Wash teeth', 'Cook some food']
# 0 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/shred_receipts0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/shred_receipts0_scene1 http://example.org/virtualhome2kg/instance/wipe_down_baseboards_please0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wipe_down_baseboards_please0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth7_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth7_scene1 http://example.org/virtualhome2kg/instance/cook_some_food4_scene1
# Executable
# ['Make toast', 'Type up document', 'Turn off light', 'Surf internet', 'Make toast', 'Type up document']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/turn_off_light0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/turn_off_light0_scene1 http://example.org/virtualhome2kg/instance/surf_internet0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/surf_internet0_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 4 updatedRoutine: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# Executable
# ['Make coffee', 'Type up document', 'Surf internet', 'Write an email', 'Keep an eye on stove as something is cooking', 'Eat']
# 0 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/surf_internet0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/surf_internet0_scene1 http://example.org/virtualhome2kg/instance/write_an_email16_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/write_an_email16_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/eat0_scene1
# Executable
# ['Wash teeth', 'Wash dishes', 'Make toast', 'Entertain', 'Wash sink', 'Wash teeth']
# 0 updated: http://example.org/virtualhome2kg/instance/wash_teeth6_scene1 http://example.org/virtualhome2kg/instance/wash_dishes0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_dishes0_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/entertain0_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth3_scene1
# not executable
# Executable
# ['Sleep', 'Wash teeth', 'Wash dishes with dishwasher', 'Relax on sofa', 'Wash sink', 'Surf net']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth2_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_teeth2_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher18_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher18_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/surf_net0_scene1
# Executable
# ['Sleep', 'Wash teeth', 'Make coffee', 'Type up document', 'Wash teeth', 'Breakfast']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth8_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_teeth8_scene1 http://example.org/virtualhome2kg/instance/make_coffee0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth0_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# Executable
# ['Make toast', 'Relax on sofa', 'Clean', 'Wash hands', 'Keep an eye on stove as something is cooking', 'Entertain']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1 http://example.org/virtualhome2kg/instance/clean3_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/clean3_scene1 http://example.org/virtualhome2kg/instance/wash_hands21_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_hands21_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# Executable
# ['Make toast', 'Type up document', 'Wash dirty dishes', 'Wash teeth', 'Breakfast', 'Relax on sofa']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_dirty_dishes0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dirty_dishes0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth8_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_teeth8_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1
# Executable
# ['Cook some food', 'Have snack', 'Turn off light', 'Wash hands', 'Cook some food', 'Drink']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food3_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/turn_off_light0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/turn_off_light0_scene1 http://example.org/virtualhome2kg/instance/wash_hands18_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_hands18_scene1 http://example.org/virtualhome2kg/instance/cook_some_food0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/cook_some_food0_scene1 http://example.org/virtualhome2kg/instance/drink22_scene1
# Executable
# ['Take nap', 'Go to toilet', 'Make toast', 'Drink', 'Put on glasses', 'Watch youtube']
# 0 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/go_to_toilet0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/go_to_toilet0_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/drink24_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/drink24_scene1 http://example.org/virtualhome2kg/instance/put_on_glasses0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/put_on_glasses0_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# Executable
# ['Make toast', 'Drink', 'Wash monitor', 'Write an email', 'Make toast', 'Have snack']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/drink22_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/drink22_scene1 http://example.org/virtualhome2kg/instance/wash_monitor0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_monitor0_scene1 http://example.org/virtualhome2kg/instance/write_an_email12_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/write_an_email12_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# Executable
# ['Sleep', 'Cut bread', 'Wash monitor', 'Watch movie', 'Read book', 'Make toast']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep2_scene1 http://example.org/virtualhome2kg/instance/cut_bread0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/cut_bread0_scene1 http://example.org/virtualhome2kg/instance/wash_monitor0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_monitor0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/read_book12_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/read_book12_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# Executable
# ['Make coffee', 'Have snack', 'Clean', 'Wash teeth', 'Surf net', 'Wash teeth']
# 0 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/clean3_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/clean3_scene1 http://example.org/virtualhome2kg/instance/wash_teeth6_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_teeth6_scene1 http://example.org/virtualhome2kg/instance/surf_net0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/surf_net0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth0_scene1
# Executable
# ['Cook some food', 'Type up document', 'Wash dishes', 'Wash hands', 'Make toast', 'Entertain']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes0_scene1 http://example.org/virtualhome2kg/instance/wash_hands22_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_hands22_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# Executable
# ['Cut bread', 'Type up document', 'Wash dishes with dishwasher', 'Put on your shoes', 'Cook some food', 'Relax on sofa']
# 0 updated: http://example.org/virtualhome2kg/instance/cut_bread0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1 http://example.org/virtualhome2kg/instance/put_on_your_shoes0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/put_on_your_shoes0_scene1 http://example.org/virtualhome2kg/instance/cook_some_food2_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/cook_some_food2_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1
# Executable
# ['Relax on sofa', 'Clean mirror', 'Surf internet', 'Watch movie', 'Relax on sofa', 'Wash hands']
# 0 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/clean_mirror0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/clean_mirror0_scene1 http://example.org/virtualhome2kg/instance/surf_internet0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/surf_internet0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa21_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa21_scene1 http://example.org/virtualhome2kg/instance/wash_hands7_scene1
# Executable
# ['Surf net', 'Keep an eye on stove as something is cooking', 'Eat', 'Wipe down sink', 'Write an email', 'Pay bills']
# 0 updated: http://example.org/virtualhome2kg/instance/surf_net0_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/eat0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/eat0_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/write_an_email15_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/write_an_email15_scene1 http://example.org/virtualhome2kg/instance/pay_bills1_scene1
# Executable
# ['Send  email', 'Drink', 'Organize closet', 'Watch movie', 'Wash teeth', 'Keep an eye on stove as something is cooking']
# 0 updated: http://example.org/virtualhome2kg/instance/send__email0_scene1 http://example.org/virtualhome2kg/instance/drink24_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/drink24_scene1 http://example.org/virtualhome2kg/instance/organize_closet0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/organize_closet0_scene1 http://example.org/virtualhome2kg/instance/watch_movie2_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie2_scene1 http://example.org/virtualhome2kg/instance/wash_teeth0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth0_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# Executable
# ['Take nap', 'Relax', 'Keep an eye on stove as something is cooking', 'Type up document', 'Wash teeth', 'Relax on sofa']
# 0 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/relax0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax0_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth3_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth3_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa27_scene1
# Executable
# ['Make coffee', 'Relax on sofa', 'Wash monitor', 'Keep an eye on stove as something is cooking', 'Relax on sofa', 'Oil dining room']
# 0 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1 http://example.org/virtualhome2kg/instance/wash_monitor0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_monitor0_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1 http://example.org/virtualhome2kg/instance/oil_dining_room0_scene1
# Executable
# ['Keep an eye on stove as something is cooking', 'Entertain', 'Shred receipts', 'Wash dishes with dishwasher', 'Oil dining room', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/entertain0_scene1 http://example.org/virtualhome2kg/instance/shred_receipts0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/shred_receipts0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1 http://example.org/virtualhome2kg/instance/oil_dining_room0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/oil_dining_room0_scene1 http://example.org/virtualhome2kg/instance/watch_movie2_scene1
# Executable
# ['Surf net', 'Entertain', 'Wash dishes', 'Write an email', 'Use computer', 'Wash dishes']
# 0 updated: http://example.org/virtualhome2kg/instance/surf_net0_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/entertain0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes2_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes2_scene1 http://example.org/virtualhome2kg/instance/write_an_email10_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/write_an_email10_scene1 http://example.org/virtualhome2kg/instance/use_computer3_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/use_computer3_scene1 http://example.org/virtualhome2kg/instance/wash_dishes5_scene1
# Executable
# ['Start computer', 'Watch movie', 'Make toast', 'Relax on sofa', 'Wash teeth', 'Relax on sofa']
# 0 updated: http://example.org/virtualhome2kg/instance/start_computer0_scene1 http://example.org/virtualhome2kg/instance/watch_movie2_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/watch_movie2_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/wash_teeth7_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth7_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa27_scene1
# Executable
# ['Go to sleep', 'Wash hands', 'Surf internet', 'Make coffee', 'Entertain', 'Watch youtube']
# 0 updated: http://example.org/virtualhome2kg/instance/go_to_sleep4_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands23_scene1 http://example.org/virtualhome2kg/instance/surf_internet0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/surf_internet0_scene1 http://example.org/virtualhome2kg/instance/make_coffee0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/entertain0_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# Executable
# ['Write an email', 'Relax on sofa', 'Write an email', 'Write an email', 'Cook some food', 'Entertain']
# 0 updated: http://example.org/virtualhome2kg/instance/write_an_email15_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1 http://example.org/virtualhome2kg/instance/write_an_email8_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/write_an_email8_scene1 http://example.org/virtualhome2kg/instance/write_an_email12_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/write_an_email12_scene1 http://example.org/virtualhome2kg/instance/cook_some_food4_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/cook_some_food4_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# Executable
# ['Watch youtube', 'Watch movie', 'Wash dishes with dishwasher', 'Read book', 'Wipe down baseboards please', 'Play musical chairs']
# 0 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/watch_movie2_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/watch_movie2_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1 http://example.org/virtualhome2kg/instance/read_book20_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/read_book20_scene1 http://example.org/virtualhome2kg/instance/wipe_down_baseboards_please0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wipe_down_baseboards_please0_scene1 http://example.org/virtualhome2kg/instance/play_musical_chairs0_scene1
# Executable
# ['Sleep', 'Wash teeth', 'Relax on sofa', 'Make toast', 'Have snack', 'Wash dishes with dishwasher']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep1_scene1 http://example.org/virtualhome2kg/instance/wash_teeth8_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_teeth8_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher19_scene1
# Executable
# ['Make toast', 'Have snack', 'Watch youtube', 'Wash sink', 'Relax on sofa', 'Breakfast']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# Executable
# ['Take nap', 'Wash hands', 'Relax on sofa', 'Organize closet', 'Relax', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/wash_hands15_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands15_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa28_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa28_scene1 http://example.org/virtualhome2kg/instance/organize_closet0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/organize_closet0_scene1 http://example.org/virtualhome2kg/instance/relax0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# Executable
# ['Make toast', 'Entertain', 'Wash dishes', 'Wash sink', 'Watch movie', 'Wash hands']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/entertain0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/entertain0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes1_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes1_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_sink0_scene1 http://example.org/virtualhome2kg/instance/watch_movie1_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/watch_movie1_scene1 http://example.org/virtualhome2kg/instance/wash_hands21_scene1
# Executable
# ['Keep an eye on stove as something is cooking', 'Have snack', 'Organize closet', 'Watch movie', 'Take shower', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/organize_closet0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/organize_closet0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/take_shower0_scene1
# 4 updatedRoutine: http://example.org/virtualhome2kg/instance/take_shower0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/take_shower0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# Executable
# ['Relax on sofa', 'Wash hands', 'Type up document', 'Write an email', 'Keep an eye on stove as something is cooking', 'Breakfast']
# 0 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1 http://example.org/virtualhome2kg/instance/wash_hands18_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands18_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/write_an_email16_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/write_an_email16_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# Executable
# ['Breakfast', 'Relax on sofa', 'Wipe down sink', 'Wash teeth', 'Read news', 'Wash dishes by hand']
# 0 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth7_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_teeth7_scene1 http://example.org/virtualhome2kg/instance/read_news0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/read_news0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_by_hand3_scene1
# Executable
# ...
# 3 updated: http://example.org/virtualhome2kg/instance/put_on_coat0_scene1 http://example.org/virtualhome2kg/instance/watch_movie2_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/watch_movie2_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# Executable
# ['Relax on sofa', 'Wash teeth', 'Wipe down baseboards please', 'Write an email', 'Wash dishes by hand', 'Chop vegetables']
# 0 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/wash_teeth2_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_teeth2_scene1 http://example.org/virtualhome2kg/instance/wipe_down_baseboards_please0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wipe_down_baseboards_please0_scene1 http://example.org/virtualhome2kg/instance/write_an_email12_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/write_an_email12_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_by_hand5_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_dishes_by_hand5_scene1 http://example.org/virtualhome2kg/instance/chop_vegetables0_scene1
# Executable
# ['Relax on sofa', 'Wash face', 'Wash dishes by hand', 'Wipe down sink', 'Wash teeth', 'Wash dishes']
# 0 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1 http://example.org/virtualhome2kg/instance/wash_face0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_face0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_by_hand0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes_by_hand0_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth8_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth8_scene1 http://example.org/virtualhome2kg/instance/wash_dishes4_scene1
# Executable
# ['Make toast', 'Relax on sofa', 'Wash monitor', 'Watch movie', 'Relax on sofa', 'Breakfast']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa26_scene1 http://example.org/virtualhome2kg/instance/wash_monitor0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_monitor0_scene1 http://example.org/virtualhome2kg/instance/watch_movie1_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/watch_movie1_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# Executable
# ['Take nap', 'Keep an eye on stove as something is cooking', 'Eat', 'Wipe down sink', 'Go to toilet', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/eat0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/eat0_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/go_to_toilet9_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/go_to_toilet9_scene1 http://example.org/virtualhome2kg/instance/watch_movie1_scene1
# Executable
# ['Surf net', 'Drink', 'Wash dishes with dishwasher', 'Chop vegetables', 'Drink', 'Wash sink']
# 0 updated: http://example.org/virtualhome2kg/instance/surf_net0_scene1 http://example.org/virtualhome2kg/instance/drink23_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/drink23_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher18_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes_with_dishwasher18_scene1 http://example.org/virtualhome2kg/instance/chop_vegetables0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/chop_vegetables0_scene1 http://example.org/virtualhome2kg/instance/drink24_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/drink24_scene1 http://example.org/virtualhome2kg/instance/wash_sink0_scene1
# Executable
# ['Make toast', 'Relax on sofa', 'Wash dishes', 'Wash hands', 'Cook some food', 'Relax on sofa']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa29_scene1 http://example.org/virtualhome2kg/instance/wash_dishes1_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_dishes1_scene1 http://example.org/virtualhome2kg/instance/wash_hands22_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_hands22_scene1 http://example.org/virtualhome2kg/instance/cook_some_food2_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/cook_some_food2_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# Executable
# ['Make coffee', 'Have snack', 'Wipe down sink', 'Wash teeth', 'Clean mirror', 'Wash hands']
# 0 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth2_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_teeth2_scene1 http://example.org/virtualhome2kg/instance/clean_mirror0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/clean_mirror0_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# Executable
# ['Sleep', 'Wipe down sink', 'Wash hands', 'Make toast', 'Eat', 'Surf net']
# 0 updated: http://example.org/virtualhome2kg/instance/sleep3_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/wash_hands22_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_hands22_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/eat0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/eat0_scene1 http://example.org/virtualhome2kg/instance/surf_net0_scene1
# Executable
# ['Cook some food', 'Have snack', 'Take shower', 'Breakfast', 'Watch movie', 'Eat']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/have_snack0_scene1 http://example.org/virtualhome2kg/instance/take_shower0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/take_shower0_scene1 http://example.org/virtualhome2kg/instance/breakfast0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/breakfast0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/eat0_scene1
# Executable
# ['Cook some food', 'Type up document', 'Clean', 'Wash face', 'Keep an eye on stove as something is cooking', 'Type up document']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food3_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/type_up_document0_scene1 http://example.org/virtualhome2kg/instance/clean1_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/clean1_scene1 http://example.org/virtualhome2kg/instance/wash_face0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_face0_scene1 http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1
# 4 updatedRoutine: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/keep_an_eye_on_stove_as_something_is_cooking0_scene1 http://example.org/virtualhome2kg/instance/type_up_document0_scene1
# Executable
# ['Cook some food', 'Drink', 'Wash hands', 'Make coffee', 'Relax on sofa', 'Wipe down sink']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food5_scene1 http://example.org/virtualhome2kg/instance/drink24_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/drink24_scene1 http://example.org/virtualhome2kg/instance/wash_hands12_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_hands12_scene1 http://example.org/virtualhome2kg/instance/make_coffee0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa28_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa28_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# Executable
# ['Make coffee', 'Relax on sofa', 'Shred receipts', 'Play games', 'Wash hands', 'Wash clothes']
# 0 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa23_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa23_scene1 http://example.org/virtualhome2kg/instance/shred_receipts0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/shred_receipts0_scene1 http://example.org/virtualhome2kg/instance/play_games0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/play_games0_scene1 http://example.org/virtualhome2kg/instance/wash_hands21_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_hands21_scene1 http://example.org/virtualhome2kg/instance/wash_clothes0_scene1
# Executable
# ['Take nap', 'Watch youtube', 'Wash face', 'Relax', 'Watch movie', 'Use computer']
# 0 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/watch_youtube0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/watch_youtube0_scene1 http://example.org/virtualhome2kg/instance/wash_face0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_face0_scene1 http://example.org/virtualhome2kg/instance/relax0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/relax0_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/watch_movie0_scene1 http://example.org/virtualhome2kg/instance/use_computer3_scene1
# Executable
# ['Relax on sofa', 'Wash hands', 'Relax on sofa', 'Take nap', 'Wash teeth', 'Browse internet']
# 0 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/wash_hands23_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa25_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa25_scene1 http://example.org/virtualhome2kg/instance/take_nap0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/take_nap0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth2_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_teeth2_scene1 http://example.org/virtualhome2kg/instance/browse_internet22_scene1
# Executable
# ['Make toast', 'Relax on sofa', 'Dust', 'Wash teeth', 'Make toast', 'Have snack']
# 0 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa28_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa28_scene1 http://example.org/virtualhome2kg/instance/dust0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/dust0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth7_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_teeth7_scene1 http://example.org/virtualhome2kg/instance/make_toast0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/make_toast0_scene1 http://example.org/virtualhome2kg/instance/have_snack0_scene1
# Executable
# ['Use computer', 'Make coffee', 'Drink', 'Wipe down sink', 'Relax on sofa', 'Wipe down sink']
# 0 updated: http://example.org/virtualhome2kg/instance/use_computer2_scene1 http://example.org/virtualhome2kg/instance/make_coffee0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/make_coffee0_scene1 http://example.org/virtualhome2kg/instance/drink15_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/drink15_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1
# 4 updatedRoutine: http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa30_scene1 http://example.org/virtualhome2kg/instance/wipe_down_sink0_scene1
# Executable
# ['Cook some food', 'Relax on sofa', 'Dust', 'Put on glasses', 'Wash dishes by hand', 'Wash monitor']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food5_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa31_scene1 http://example.org/virtualhome2kg/instance/dust0_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/dust0_scene1 http://example.org/virtualhome2kg/instance/put_on_glasses0_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/put_on_glasses0_scene1 http://example.org/virtualhome2kg/instance/wash_dishes_by_hand6_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_dishes_by_hand6_scene1 http://example.org/virtualhome2kg/instance/wash_monitor0_scene1
# Executable
# ['Cook some food', 'Relax on sofa', 'Wash hands', 'Wash dishes', 'Wash hands', 'Watch movie']
# 0 updated: http://example.org/virtualhome2kg/instance/cook_some_food0_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa19_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa19_scene1 http://example.org/virtualhome2kg/instance/wash_hands17_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_hands17_scene1 http://example.org/virtualhome2kg/instance/wash_dishes3_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/wash_dishes3_scene1 http://example.org/virtualhome2kg/instance/wash_hands23_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/wash_hands23_scene1 http://example.org/virtualhome2kg/instance/watch_movie0_scene1
# Executable
# ['Wash teeth', 'Surf internet', 'Wash teeth', 'Relax on sofa', 'Surf net', 'Write an email']
# 0 updated: http://example.org/virtualhome2kg/instance/wash_teeth0_scene1 http://example.org/virtualhome2kg/instance/surf_internet0_scene1
# 1 updated: http://example.org/virtualhome2kg/instance/surf_internet0_scene1 http://example.org/virtualhome2kg/instance/wash_teeth7_scene1
# 2 updated: http://example.org/virtualhome2kg/instance/wash_teeth7_scene1 http://example.org/virtualhome2kg/instance/relax_on_sofa27_scene1
# 3 updated: http://example.org/virtualhome2kg/instance/relax_on_sofa27_scene1 http://example.org/virtualhome2kg/instance/surf_net0_scene1
# 4 updated: http://example.org/virtualhome2kg/instance/surf_net0_scene1 http://example.org/virtualhome2kg/instance/write_an_email16_scene1

# %%
activityMap
# Out:
# {'http://example.org/virtualhome2kg/instance/wash_teeth0_scene1': {'startState': ['http://example.org/virtualhome2kg/instance/state0_bathroom11_wash_teeth0_scene1'],
#   'endState': ['http://example.org/virtualhome2kg/instance/state8_teeth1003_wash_teeth0_scene1']},
#  'http://example.org/virtualhome2kg/instance/surf_internet0_scene1': {'startState': ['http://example.org/virtualhome2kg/instance/state0_home_office336_surf_internet0_scene1'],
#   'endState': ['http://example.org/virtualhome2kg/instance/state11_keyboard432_surf_internet0_scene1']},
#  'http://example.org/virtualhome2kg/instance/wash_teeth7_scene1': {'startState': ['http://example.org/virtualhome2kg/instance/state0_bathroom11_wash_teeth7_scene1'],
#   'endState': ['http://example.org/virtualhome2kg/instance/state18_light73_wash_teeth7_scene1']},
#  'http://example.org/virtualhome2kg/instance/relax_on_sofa27_scene1': {'startState': ['http://example.org/virtualhome2kg/instance/state0_home_office336_relax_on_sofa27_scene1'],
#   'endState': ['http://example.org/virtualhome2kg/instance/state4_couch369_relax_on_sofa27_scene1']},
#  'http://example.org/virtualhome2kg/instance/write_an_email16_scene1': {'startState': ['http://example.org/virtualhome2kg/instance/state0_home_office336_write_an_email16_scene1'],
#   'endState': ['http://example.org/virtualhome2kg/instance/state11_keyboard432_write_an_email16_scene1']}}

# %%
executable_routine
# Out:
# 10
