# %% [markdown]
# This is a script for simulating arbitrary activity and export its results.

# %%
# %matplotlib notebook
import IPython.display
from utils_demo import *
from sys import platform
import sys
from PIL import Image
import matplotlib.pyplot as plt
import json
import rdflib
import glob
import os
import re
import copy
import time

sys.path.append('../simulation')
sys.path.append('../dataset_utils/')

import numpy as np
import random
import cv2
import add_preconds
import evolving_graph.check_programs as check_programs
import evolving_graph.utils as utils

from unity_simulator.comm_unity import UnityCommunication

# %%
comm = UnityCommunication()

# %% [markdown]
# Select scene number.
# Please see https://github.com/xavierpuigf/virtualhome/tree/master/simulation#environment .
#
# If you want to use the existing activity data provided by VirtualHome, you can load the dataset.
# Please see the below link for getting the dataset. (Note that there are many errors in the dataset.)
# https://github.com/xavierpuigf/virtualhome#dataset

# %%
scene = 1
scene_graph = "TrimmedTestScene" + str(scene) + "_graph"
executable_program_path = "../dataset/programs_processed_precond_nograb_morepreconds/executable_programs/" + scene_graph + "/*/*.txt"
executable_program_list = []
for file_path in glob.glob(executable_program_path):
    executable_program_list.append(file_path.replace("../dataset/programs_processed_precond_nograb_morepreconds/executable_programs/" + scene_graph + "/", ""))

# %% [markdown]
# The HomeOntology is used for randomly selecting an activity.
# Load HomeOntology as RDF graph.
# If you do not select an activity randomly, you do not have to use the HomeOntology.

# %%
rdf_g = rdflib.Graph()
rdf_g.parse("../ontology/vh2kg_ontology.ttl", format="ttl")
# Out:
# <Graph identifier=N9114051663ed4b098b6a43ff7e99f34d (<class 'rdflib.graph.Graph'>)>

# %%
def get_activity_from_ontology(activity_type):
    results = []
    qres = rdf_g.query(
    """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX : <http://www.owl-ontologies.com/VirtualHome.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
select ?activity where { 
    # ?activity rdfs:subClassOf :%s .
 } 
       """ % activity_type)

    result = ""
    for row in qres:
        activity = "".join(row).replace("http://www.owl-ontologies.com/VirtualHome.owl#","")
        arr = activity.split("_")
        arr[0] = arr[0].capitalize()
        activity = " ".join(arr)
        result = activity
        results.append(result)
    return results

# %%
def generate_list_of_steps(file_path):
    file = open(file_path, "r", encoding="utf-8")
    i = 0
    list_of_steps = []
    program_name = ""
    description = ""
    char= "<char0>"
    while True:
        line = file.readline()
        if line:
            line = line.replace("\n","")
            if i==0:
                program_name = line
            elif i==1:
                description = line
            elif line.startswith("["):
                list_of_steps.append(line)
            else:
                pass
            i+=1
        else:
            break
    return program_name, description, list_of_steps

# %%
def get_activity_program(category):
    #unexecutable = ["Take shower", "Take shoes off", "Wash teeth", "Wash face", "Dust", "Clean toilet", "Clean room", "Scrubbing living room tile floor is once week activity for me", "Clean mirror", "Play games", "Play on laptop", "Read on sofa"]
    unexecutable = []
    executable = []
    activities = get_activity_from_ontology(category)
    for activity_name in activities:
        if activity_name in unexecutable:
            continue
        results = [program for program in program_list if program["name"] == activity_name]
        if len(results) == 0:
            print("Nothing: " + activity_name)
        else:
            print("Success: " + activity_name)
            executable.append({"activity_name": activity_name, "results": results})
    return executable

# %%
data_path = "../dataset/programs_processed_precond_nograb_morepreconds/withoutconds/*/*.txt"
program_list = []
for file_path in glob.glob(data_path):
    file_name = file_path.replace("../dataset/programs_processed_precond_nograb_morepreconds/withoutconds/", "")
    if file_name in executable_program_list:
        program_name, description, list_of_steps = generate_list_of_steps(file_path)
        program_list.append({
            "file_name":file_name,
            "name": program_name,
            "description": description,
            "list_of_steps": list_of_steps
        })

# %%
activity_list = []
executable_activity_list = get_activity_program("Leisure")
# Out:
# Success: Listen to music
# Nothing: Turn off tv
# Nothing: Juggling
# Success: Relax on sofa
# Success: Play games
# Success: Browse computer
# Nothing: Eat while watching tv
# Nothing: Social media  checks
# Nothing: Play piano
# Success: Relax
# Success: Read magazine
# Success: Play musical chairs
# Nothing: Read on sofa
# Nothing: Change tv channels
# Nothing: In living room i eat dinner
# Success: Read newspaper
# Success: Surf net
# Success: Watch  horror  movie
# Nothing: Play
# Nothing: Turn on tv
# Nothing: Sing song
# Success: Turn on radio
# Nothing: Tabletop game
# Success: Surf internet
# Success: Read news
# Nothing: Practice own singing
# Success: Movie
# Nothing: Turn on tv with remote
# Nothing: Dance
# Nothing: Playtime lunch with dolls
# Success: Read book
# Success: Browse internet
# Nothing: Play with barbies
# Success: Playing video game
# Nothing: Watch tv
# Nothing: Read yourself to sleep
# Nothing: Play on laptop
# Nothing: Sing karaoke
# Nothing: Play guitar
# Nothing: Practice violin
# Success: Watch movie
# Success: Watch youtube

# %%
unsupport_unity_exec_time = {
    "Wipe": 5.0,
    "PutOn": 10.0,
    "PutOff": 10.0,
    "Greet": 3.0,
    "Drop": 2.0,
    "Read": 1800.0,
    "Lie": 5.0,
    "Pour": 5.0,
    "Type": 10.0,
    "Watch": 7200.0,
    "Move": 5.0,
    "Wash": 10.0,
    "Squeeze": 5.0,
    "PlugIn": 5.0,
    "PlugOut": 5.0,
    "Cut": 5.0,
    "Eat": 1200.0,
    "Sleep": 21600.0,
    "Wake": 5.0
}

# %%
def check_unsupport_action(script):
    flag = True
    for line in script:
        m = re.search(r'\[.+\]', line)
        action = m.group().replace('[', '')
        action = action.replace(']', '')
        if action in [x for x in unsupport_unity_exec_time.keys()]:
            flag = False
            break
    return flag

# %%
def export(activity_name, graph_state_list, activity_cnt, time_list):
    os.mkdir("graph_state_list_with_bbox/scene" + str(scene) + "/" + activity_name + "/" + activity_cnt)
    state_cnt = 0
    for graph_state in graph_state_list:
        state_cnt += 1
        file_path = "graph_state_list_with_bbox/scene" + str(scene) + "/"  + activity_name + "/" + activity_cnt + "/activityList-graph-state-" + '{0:03d}'.format(state_cnt) + ".json"
        with open(file_path, 'w') as outfile:
            json.dump(graph_state, outfile)

    with open("graph_state_list_with_bbox/scene" + str(scene) + "/" + activity_name + "/" + activity_cnt + "/activityList-program.txt", 'w') as f:
        for s in executed_program:
            f.write("%s\n" % s)

    with open("graph_state_list_with_bbox/scene" + str(scene) + "/" + activity_name + "/" + activity_cnt + "/program-description.txt", 'w') as f:
        f.write("%s\n" % activity["name"])
        f.write("%s\n" % activity["description"])
        
    time_list = [str(time) for time in time_list]
    duration = "\n".join(time_list)
    with open("graph_state_list_with_bbox/scene" + str(scene) + "/" + activity_name + "/" + activity_cnt + "/duration.txt", 'w') as f:
        f.write(duration)

# %%
def update_bbox(pre_graph, current_graph):
    try:
        new_graph= copy.deepcopy(current_graph)
        
        for pre_node in pre_graph["nodes"]:
            for new_node in new_graph["nodes"]:
                if new_node["id"] == pre_node["id"]:
                    new_node["bounding_box"] = pre_node["bounding_box"]
           
    except Exception as e:
        print(e)
    
    return new_graph

# %%
def delete2000(graph_state_list):
    new_graph_state_list = []
    for graph_state in graph_state_list:
        new_nodes = [x for x in graph_state["nodes"] if x["id"] < 2000]
        new_edges = [x for x in graph_state["edges"] if x["from_id"] < 2000 and x["to_id"] < 2000]
        new_graph_state_list.append({"nodes": new_nodes, "edges": new_edges})
    return new_graph_state_list

# %%
for executable_activity in executable_activity_list:
    activity_list = executable_activity["results"]
    activity_name = executable_activity["activity_name"]
    activity_cnt = 0
    try:
        os.mkdir("graph_state_list_with_bbox/scene" + str(scene) + "/" + activity_name)
        for activity in activity_list:
            try:
                new_graph_state_list = []
                time_list = []
                comm.reset(scene-1)
                comm.add_character('chars/Female2')
                success, g = comm.environment_graph();
                print(activity["file_name"])
                script = activity["list_of_steps"]
                executable_program = []
                for x in script:
                    executable_program.append("<char0> " + x)
                executable_program

                # check if supported action
                if check_unsupport_action(script) == False:
                    continue
                
                preconds = add_preconds.get_preconds_script(script).printCondsJSON()
                g = check_programs.translate_graph_dict_nofile(g)
                info = check_programs.check_script(script, preconds, graph_path=None, inp_graph_dict=g)
                message, final_state, graph_state_list, graph_dict, id_mapping, info, helper, executed_script = info
                # if delete randomly placced objects 
                graph_state_list = delete2000(graph_state_list)
                print(message)
                executed_program = []
                for x in executed_script:
                    executed_program.append("<char0> " + re.sub("\[\d+\]","",x.__str__()).strip())

                if message != "Script is executable":
                    continue
                    
                i = 0
                comm.expand_scene(graph_state_list[0])
                success, g = comm.environment_graph()
                g = update_bbox(g, graph_state_list[i])
                new_graph_state_list.append(copy.deepcopy(g))

                for instruction in executed_program:
                    i += 1
                    start = time.time()
                    success, message = comm.render_script(script=[instruction],
                                              #processing_time_limit=80,
                                              find_solution=False,
                                              #image_width=320,
                                              #image_height=240,  
                                              #skip_animation=False,
                                              recording=True,
                                              #gen_vid=False,
                                              #save_scene_states=True,
                                              #file_name_prefix='FoodPreparation',
                                              frame_rate=10
                                             )
                    time_list.append(time.time() - start)
                    success, g = comm.environment_graph()
                    print(str(success) + ": " + str(instruction))
                    g = update_bbox(g, graph_state_list[i])
                    new_graph_state_list.append(copy.deepcopy(g))

                export(activity_name, new_graph_state_list, str(activity_cnt), time_list)
                activity_cnt += 1
            except Exception as e:
                print(e.args)
    except Exception as e:
        print(e.args)
# Out:
# results_intentions_march-13-18/file263_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file737_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file385_2.txt
# ('cd_player',)
# results_intentions_march-13-18/file199_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <stereo> (1001)
# True: <char0> [FIND] <stereo> (1001)
# True: <char0> [FIND] <button> (1000)
# True: <char0> [PUSH] <button> (1000)
# True: <char0> [FIND] <button> (1002)
# True: <char0> [PUSH] <button> (1002)
# results_intentions_march-13-18/file363_2.txt
# ('dvd_player',)
# results_intentions_march-13-18/file305_2.txt
# Script is executable
# True: <char0> [WALK] <bedroom> (75)
# True: <char0> [WALK] <light> (176)
# True: <char0> [FIND] <light> (176)
# True: <char0> [SWITCHON] <light> (176)
# True: <char0> [WALK] <desk> (111)
# True: <char0> [FIND] <chair> (110)
# True: <char0> [SIT] <chair> (110)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file23_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file59_1.txt
# results_intentions_march-13-18/file161_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file415_1.txt
# results_intentions_march-13-18/file773_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file113_1.txt
# ('cd_player',)
# results_intentions_march-13-18/file14_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <stereo> (1001)
# True: <char0> [FIND] <stereo> (1001)
# True: <char0> [TURNTO] <stereo> (1001)
# True: <char0> [LOOKAT] <stereo> (1001)
# True: <char0> [FIND] <button> (1000)
# True: <char0> [GRAB] <button> (1000)
# results_intentions_march-13-18/file547_2.txt
# Script is executable
# True: <char0> [WALK] <bedroom> (75)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [TOUCH] <stereo> (1000)
# True: <char0> [TURNTO] <stereo> (1000)
# results_intentions_march-13-18/file463_2.txt
# Script is executable
# True: <char0> [WALK] <bedroom> (75)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file1049_1.txt
# ('dvd_player',)
# results_intentions_march-13-18/file953_1.txt
# ('cd_player',)
# results_intentions_march-13-18/file503_2.txt
# ('cd_player',)
# results_intentions_march-13-18/file173_1.txt
# results_intentions_march-13-18/file403_1.txt
# Script is executable
# True: <char0> [WALK] <bedroom> (75)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file910_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <stereo> (1000)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# results_intentions_march-13-18/file462_2.txt
# results_intentions_march-13-18/file416_1.txt
# results_intentions_march-13-18/file204_2.txt
# results_intentions_march-13-18/file387_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file473_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file674_2.txt
# results_intentions_march-13-18/file455_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file300_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file490_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file570_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file124_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file941_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file793_2.txt
# results_intentions_march-13-18/file321_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# True: <char0> [FIND] <water_glass> (1000)
# True: <char0> [GRAB] <water_glass> (1000)
# True: <char0> [DRINK] <water_glass> (1000)
# results_intentions_march-13-18/file449_1.txt
# results_intentions_march-13-18/file456_2.txt
# results_intentions_march-13-18/file299_1.txt
# results_intentions_march-13-18/file379_2.txt
# results_intentions_march-13-18/file6_1.txt
# results_intentions_march-13-18/file563_1.txt
# results_intentions_march-13-18/file137_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file742_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file268_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <light> (428)
# True: <char0> [FIND] <light> (428)
# True: <char0> [SWITCHON] <light> (428)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file976_1.txt
# results_intentions_march-13-18/file332_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file297_2.txt
# results_intentions_march-13-18/file762_2.txt
# results_intentions_march-13-18/file567_2.txt
# results_intentions_march-13-18/file447_2.txt
# results_intentions_march-13-18/file438_1.txt
# results_intentions_march-13-18/file798_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file442_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file390_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file932_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_intentions_march-13-18/file96_1.txt
# results_intentions_march-13-18/file3_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [FIND] <couch> (369)
# True: <char0> [WALK] <couch> (369)
# True: <char0> [SIT] <couch> (369)
# results_text_rebuttal_specialparsed_programs_turk_third/split109_1.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split101_4.txt
# ('video_game_console',)
# results_text_rebuttal_specialparsed_programs_turk_third/split92_3.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <board_game> (1000)
# True: <char0> [FIND] <board_game> (1000)
# True: <char0> [GRAB] <board_game> (1000)
# True: <char0> [WALK] <dining_room> (208)
# True: <char0> [WALK] <table> (232)
# True: <char0> [PUTBACK] <board_game> (1000) <table> (232)
# results_text_rebuttal_specialparsed_programs_turk_third/split65_1.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split26_4.txt
# results_text_rebuttal_specialparsed_programs_turk_robot/split64_2.txt
# results_text_rebuttal_specialparsed_programs_upwork_july/split13_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <chair> (1002)
# True: <char0> [FIND] <chair> (1002)
# True: <char0> [PULL] <chair> (1002)
# True: <char0> [FIND] <chair> (1001)
# True: <char0> [PULL] <chair> (1001)
# True: <char0> [FIND] <chair> (373)
# True: <char0> [PULL] <chair> (373)
# True: <char0> [FIND] <stereo> (1000)
# True: <char0> [SWITCHON] <stereo> (1000)
# True: <char0> [SWITCHOFF] <stereo> (1000)
# True: <char0> [RUN] <chair> (1002)
# True: <char0> [SIT] <chair> (1002)
# True: <char0> [STANDUP]
# True: <char0> [SWITCHON] <stereo> (1000)
# True: <char0> [SWITCHOFF] <stereo> (1000)
# True: <char0> [RUN] <chair> (1001)
# True: <char0> [SIT] <chair> (1001)
# True: <char0> [STANDUP]
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split1_5.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split3_3.txt
# results_text_rebuttal_specialparsed_programs_upwork_july/split22_9.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split2_4.txt
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split10_2.txt
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split1_6.txt
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split8_3.txt
# results_text_rebuttal_specialparsed_programs_upwork_july/split15_4.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split124_2.txt
# ('cd_player',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split2_1.txt
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split91_1.txt
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split70_1.txt
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split5_5.txt
# results_intentions_march-13-18/file341_1.txt
# results_intentions_march-13-18/file241_2.txt
# results_intentions_march-13-18/file243_1.txt
# results_intentions_march-13-18/file821_1.txt
# results_intentions_march-13-18/file628_1.txt
# results_intentions_march-13-18/file617_2.txt
# results_intentions_march-13-18/file508_2.txt
# results_intentions_march-13-18/file163_1.txt
# results_intentions_march-13-18/file1087_1.txt
# results_intentions_march-13-18/file23_2.txt
# results_intentions_march-13-18/file630_1.txt
# results_intentions_march-13-18/file693_2.txt
# results_intentions_march-13-18/file688_2.txt
# results_intentions_march-13-18/file86_1.txt
# results_intentions_march-13-18/file221_2.txt
# results_intentions_march-13-18/file896_2.txt
# results_intentions_march-13-18/file524_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file16_2.txt
# results_intentions_march-13-18/file57_1.txt
# results_intentions_march-13-18/file192_1.txt
# results_intentions_march-13-18/file504_2.txt
# results_intentions_march-13-18/file544_1.txt
# results_intentions_march-13-18/file1073_1.txt
# results_intentions_march-13-18/file15_2.txt
# results_intentions_march-13-18/file208_2.txt
# results_intentions_march-13-18/file897_2.txt
# results_intentions_march-13-18/file1088_1.txt
# results_intentions_march-13-18/file484_1.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split3_4.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split27_3.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split146_1.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split28_2.txt
# results_text_rebuttal_specialparsed_programs_upwork_july/split11_5.txt
# results_intentions_march-13-18/file1046_1.txt
# results_intentions_march-13-18/file365_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <chair> (373)
# True: <char0> [SIT] <chair> (373)
# True: <char0> [SWITCHON] <computer> (434)
# results_intentions_march-13-18/file263_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# True: <char0> [TURNTO] <computer> (434)
# True: <char0> [LOOKAT] <computer> (434)
# results_intentions_march-13-18/file385_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [WALK] <desk> (374)
# True: <char0> [FIND] <chair> (373)
# True: <char0> [SIT] <chair> (373)
# True: <char0> [SWITCHON] <computer> (434)
# results_intentions_march-13-18/file246_1.txt
# Script is executable
# True: <char0> [STANDUP]
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# True: <char0> [FIND] <mouse> (430)
# True: <char0> [GRAB] <mouse> (430)
# True: <char0> [FIND] <button> (1000)
# True: <char0> [TURNTO] <button> (1000)
# True: <char0> [LOOKAT] <button> (1000)
# results_intentions_march-13-18/file187_2.txt
# results_intentions_march-13-18/file145_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <desk> (374)
# True: <char0> [FIND] <chair> (373)
# True: <char0> [SIT] <chair> (373)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# results_intentions_march-13-18/file1047_1.txt
# results_intentions_march-13-18/file60_1.txt
# results_intentions_march-13-18/file384_1.txt
# results_intentions_march-13-18/file1043_2.txt
# results_intentions_march-13-18/file282_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# results_intentions_march-13-18/file169_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file393_1.txt
# results_intentions_march-13-18/file406_1.txt
# results_intentions_march-13-18/file928_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file275_1.txt
# Script is executable
# True: <char0> [WALK] <bedroom> (75)
# True: <char0> [WALK] <chair> (110)
# True: <char0> [FIND] <chair> (110)
# True: <char0> [SIT] <chair> (110)
# True: <char0> [FIND] <computer> (177)
# True: <char0> [SWITCHON] <computer> (177)
# True: <char0> [FIND] <newspaper> (1000)
# results_intentions_march-13-18/file371_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# True: <char0> [TURNTO] <computer> (434)
# True: <char0> [LOOKAT] <computer> (434)
# results_intentions_march-13-18/file426_1.txt
# results_intentions_march-13-18/file216_1.txt
# results_intentions_march-13-18/file71_2.txt
# results_intentions_march-13-18/file527_2.txt
# results_intentions_march-13-18/file624_1.txt
# results_intentions_march-13-18/file810_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <desk> (374)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# True: <char0> [FIND] <chair> (373)
# True: <char0> [SIT] <chair> (373)
# True: <char0> [FIND] <mouse> (430)
# True: <char0> [TOUCH] <mouse> (430)
# True: <char0> [TURNTO] <computer> (434)
# True: <char0> [LOOKAT] <computer> (434)
# results_intentions_march-13-18/file7_1.txt
# results_intentions_march-13-18/file521_2.txt
# results_intentions_march-13-18/file274_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <chair> (373)
# True: <char0> [FIND] <chair> (373)
# True: <char0> [SIT] <chair> (373)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [TURNTO] <computer> (434)
# True: <char0> [LOOKAT] <computer> (434)
# results_intentions_march-13-18/file446_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <computer> (434)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# True: <char0> [TURNTO] <computer> (434)
# True: <char0> [LOOKAT] <computer> (434)
# results_intentions_march-13-18/file13_2.txt
# results_intentions_march-13-18/file394_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file540_1.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <phone> (1000)
# True: <char0> [FIND] <phone> (1000)
# True: <char0> [GRAB] <phone> (1000)
# True: <char0> [TOUCH] <phone> (1000)
# True: <char0> [TURNTO] <phone> (1000)
# True: <char0> [LOOKAT] <phone> (1000)
# results_text_rebuttal_specialparsed_programs_turk_third/split74_4.txt
# ('video_game_console',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split159_3.txt
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split30_1.txt
# results_text_rebuttal_specialparsed_programs_turk_third/split107_4.txt
# results_text_rebuttal_specialparsed_programs_upwork_july/split9_4.txt
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split28_2.txt
# Script is executable
# True: <char0> [WALK] <home_office> (336)
# True: <char0> [WALK] <chair> (373)
# True: <char0> [FIND] <chair> (373)
# True: <char0> [SIT] <chair> (373)
# True: <char0> [FIND] <computer> (434)
# True: <char0> [SWITCHON] <computer> (434)
# True: <char0> [TURNTO] <computer> (434)
# True: <char0> [LOOKAT] <computer> (434)
# results_text_rebuttal_specialparsed_programs_turk_third/split36_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
